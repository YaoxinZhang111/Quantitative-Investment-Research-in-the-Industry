# %%
import pandas as pd

f1 = pd.read_csv('./log/profit.csv')
f2 = pd.read_csv('./log/deficit.csv')

f3=pd.concat([f1,f2])
f3
# Out:
#     industry           code    buy_date   sell_date  buy_price  sell_price  \
# 0         白酒  sz.002304.csv  2014-11-28  2014-12-26      67.20       78.69
# 1         白酒  sh.600779.csv  2015-05-11  2015-06-01      11.41       13.32
# 2         白酒  sz.000995.csv  2014-11-28  2015-08-19      11.96       14.34
# 3         白酒  sz.000596.csv  2014-11-28  2014-12-22      29.36       34.08
# 4         白酒  sz.000596.csv  2015-05-11  2015-06-12      37.19       43.31
# ..       ...            ...         ...         ...        ...         ...
# 342    自动化设备  sz.000988.csv  2020-02-25  2020-02-28      23.17       21.13
# 343    自动化设备  sz.000584.csv  2020-02-25  2020-03-20       6.24        5.90
# 344    自动化设备  sz.002334.csv  2020-02-25  2020-03-11       7.11        6.21
# 345    自动化设备  sz.002334.csv  2020-09-30  2020-11-10       6.14        5.73
# 346    自动化设备  sz.002334.csv  2020-10-09  2020-11-10       6.14        5.73
#
#      pct_reward
# 0      0.170982
# 1      0.167397
# ...

# %%
from config import STOCK_LIST
print(STOCK_LIST)
# Out:
# ['sz.002538.csv', 'sh.600697.csv', 'sh.605089.csv', 'sz.301089.csv', 'sh.600683.csv', 'sh.600873.csv', 'sz.002504.csv', 'sz.002262.csv', 'sz.002276.csv', 'sz.002510.csv', 'sh.600867.csv', 'sz.399005.csv', 'sh.600654.csv', 'sh.600132.csv', 'sh.601238.csv', 'sz.002289.csv', 'sh.600126.csv', 'sh.600640.csv', 'sh.600898.csv', 'sz.399011.csv', 'sh.600668.csv', 'sz.301076.csv', 'sz.301062.csv', 'sz.399993.csv', 'sz.000893.csv', 'sh.603822.csv', 'sh.000816.csv', 'sh.600495.csv', 'sh.600481.csv', 'sz.001227.csv', 'sh.000802.csv', 'sh.603188.csv', 'sz.000887.csv', 'sh.603836.csv', 'sz.002048.csv', 'sz.000677.csv', 'sz.002060.csv', 'sz.002706.csv', 'sz.002712.csv', 'sz.002074.csv', 'sz.000663.csv', 'sz.000850.csv', 'sz.000688.csv', 'sh.603639.csv', 'sh.600330.csv', 'sz.301248.csv', 'sh.601990.csv', 'sh.600456.csv', 'sz.002921.csv', 'sz.002935.csv', 'sh.601012.csv', 'sh.603605.csv', 'sz.002909.csv', 'sh.603177.csv', 'sz.000878.csv', 'sh.603611.csv', 'sh.600318.csv', 'sh.601006.csv', 'sh.600287.
# ...

# %% [markdown]
# vol>5>10,跌5，三天10，8，15止盈，     7，8天跑
